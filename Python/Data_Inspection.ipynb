# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set()

# %%
path = '../Dataset/simulation_matrix_updated_info.csv'
data = pd.read_csv(path)

data
# Out:
#                       ID  Blade_Length_m  Root_Chord_mm      Material  \
# 0     BL0.8_C150_AL_P500             0.8            150     Aluminium
# 1    BL0.8_C150_AL_P1000             0.8            150     Aluminium
# 2    BL0.8_C150_AL_P1500             0.8            150     Aluminium
# 3    BL0.8_C150_FBG_P500             0.8            150    Fiberglass
# 4   BL0.8_C150_FBG_P1000             0.8            150    Fiberglass
# ..                   ...             ...            ...           ...
# 76  BL1.6_C300_FBG_P1000             1.6            300    Fiberglass
# 77  BL1.6_C300_FBG_P1500             1.6            300    Fiberglass
# 78   BL1.6_C300_CBF_P500             1.6            300  Carbon fiber
# 79  BL1.6_C300_CBF_P1000             1.6            300  Carbon fiber
# 80  BL1.6_C300_CBF_P1500             1.6            300  Carbon fiber
#
#     Applied_Load_Pa   Status  Max_Deformation_m Max_Equiv_Stress_Pa
# ...

# %%
data.head()
# Out:
#                      ID  Blade_Length_m  Root_Chord_mm    Material  \
# 0    BL0.8_C150_AL_P500             0.8            150   Aluminium
# 1   BL0.8_C150_AL_P1000             0.8            150   Aluminium
# 2   BL0.8_C150_AL_P1500             0.8            150   Aluminium
# 3   BL0.8_C150_FBG_P500             0.8            150  Fiberglass
# 4  BL0.8_C150_FBG_P1000             0.8            150  Fiberglass
#
#    Applied_Load_Pa   Status  Max_Deformation_m Max_Equiv_Stress_Pa
# 0              500  Updated           0.002438          4.2995 e+6
# 1             1000  Updated           0.004875          8.5991 e+6
# 2             1500  Updated           0.007313          1.2899 e+7
# 3              500  Updated           0.006742          4.3042 e+6
# 4             1000  Updated           0.013483          8.6085 e+6

# %%
data.tail()
# Out:
#                       ID  Blade_Length_m  Root_Chord_mm      Material  \
# 76  BL1.6_C300_FBG_P1000             1.6            300    Fiberglass
# 77  BL1.6_C300_FBG_P1500             1.6            300    Fiberglass
# 78   BL1.6_C300_CBF_P500             1.6            300  Carbon fiber
# 79  BL1.6_C300_CBF_P1000             1.6            300  Carbon fiber
# 80  BL1.6_C300_CBF_P1500             1.6            300  Carbon fiber
#
#     Applied_Load_Pa   Status  Max_Deformation_m Max_Equiv_Stress_Pa
# 76             1000  Updated           0.027693          8.6208 e+6
# 77             1500  Updated           0.041539          1.2931 e+7
# 78              500  Updated           0.002883          4.3078 e+6
# 79             1000  Updated           0.005766          8.6156 e+6
# 80             1500  Updated           0.008649          1.2923 e+7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   81 non-null     object
#  1   Blade_Length_m       81 non-null     float64
#  2   Root_Chord_mm        81 non-null     int64
#  3   Material             81 non-null     object
#  4   Applied_Load_Pa      81 non-null     int64
#  5   Status               81 non-null     object
#  6   Max_Deformation_m    81 non-null     float64
#  7   Max_Equiv_Stress_Pa  81 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.2+ KB

# %%
data.describe()
# Out:
#        Blade_Length_m  Root_Chord_mm  Applied_Load_Pa  Max_Deformation_m
# count       81.000000      81.000000        81.000000          81.000000
# mean         1.200000     216.666667      1000.000000           0.026474
# std          0.328634      62.749502       410.791918           0.048079
# min          0.800000     150.000000       500.000000           0.000198
# 25%          0.800000     150.000000       500.000000           0.002850
# 50%          1.200000     200.000000      1000.000000           0.009020
# 75%          1.600000     300.000000      1500.000000           0.028399
# max          1.600000     300.000000      1500.000000           0.315080

# %%
data.shape
# Out:
# (81, 8)

# %%
data.columns
# Out:
# Index(['ID', 'Blade_Length_m', 'Root_Chord_mm', 'Material', 'Applied_Load_Pa',
#        'Status', 'Max_Deformation_m', 'Max_Equiv_Stress_Pa'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ID                     0
# Blade_Length_m         0
# Root_Chord_mm          0
# Material               0
# Applied_Load_Pa        0
# Status                 0
# Max_Deformation_m      0
# Max_Equiv_Stress_Pa    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# ID                      object
# Blade_Length_m         float64
# Root_Chord_mm            int64
# Material                object
# Applied_Load_Pa          int64
# Status                  object
# Max_Deformation_m      float64
# Max_Equiv_Stress_Pa     object
# dtype: object

# %%
# Max_Equiv_Stress_Pa is object because the values are written as a string and not as a number in python

data["Max_Equiv_Stress_Pa"] = data["Max_Equiv_Stress_Pa"].astype(str).str.replace(" ", "")
data["Max_Equiv_Stress_Pa"]   = data["Max_Equiv_Stress_Pa"].astype(float)

# %%
data.dtypes
# Out:
# ID                      object
# Blade_Length_m         float64
# Root_Chord_mm            int64
# Material                object
# Applied_Load_Pa          int64
# Status                  object
# Max_Deformation_m      float64
# Max_Equiv_Stress_Pa    float64
# dtype: object

# %%
# Correlation Matrix
corr = data.corr( numeric_only = True)

sns.heatmap( data = corr, annot = True)
# Out:
# <Axes: >

# %%
# Save changes to original
data.to_csv(path, index=False)

# Save backup
data.to_csv(path.replace(".csv", "_backup.csv"), index=False)
